# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\edwin\\OneDrive\\Desktop\\development_journey\\20.Machine Learning\\regression\\salary\\case_study.ipynb")

# %%
df
# Out:
#    exp  salary
# 0    1    8000
# 1    2   12000
# 2    3   25000
# 3    4   35000
# 4    5   48000
# 5    6   60000

# %%
sns.regplot(x="exp",y="salary",data=df)
plt.grid()

# %%
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]

# %%
X.head()
# Out:
#    exp
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %%
Y.head()
# Out:
# 0     8000
# 1    12000
# 2    25000
# 3    35000
# 4    48000
# Name: salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.coef_ # slope(m)
# Out:
# array([11800.])

# %%
lr.intercept_ # c=constant
# Out:
# np.float64(-11100.000000000007)
