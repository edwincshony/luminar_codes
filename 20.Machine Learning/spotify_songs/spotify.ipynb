# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("spotify_preprocessing_dataset.csv")
df
# Out:
#                 Track            Artist        Genre  DurationSec  Popularity  \
# 0     Blinding Lights        The Weeknd          Pop          303          73
# 1          Levitating          Dua Lipa          Pop          162          88
# 2        Shape of You        Ed Sheeran          Pop          190          92
# 3                Stay     The Kid LAROI      Hip-Hop          180          92
# 4             Peaches     Justin Bieber          R&B          237          73
# 5             Bad Guy     Billie Eilish  Alternative          171          99
# 6           Sunflower       Post Malone      Hip-Hop          189          92
# 7              Closer  The Chainsmokers          EDM          165          82
# 8    Watermelon Sugar      Harry Styles          Pop          319          99
# 9           As It Was      Harry Styles          Pop          258          82
# 10           Senorita      Shawn Mendes    Latin Pop          198          96
# ...

# %%
df.shape
# Out:
# (16, 11)

# %%
df.columns
# Out:
# Index(['Track', 'Artist', 'Genre', 'DurationSec', 'Popularity', 'Danceability',
#        'Energy', 'Tempo', 'Loudness', 'Acousticness', 'StreamsMillions'],
#       dtype='object')

# %%
df.head()
# Out:
#              Track         Artist    Genre  DurationSec  Popularity  \
# 0  Blinding Lights     The Weeknd      Pop          303          73
# 1       Levitating       Dua Lipa      Pop          162          88
# 2     Shape of You     Ed Sheeran      Pop          190          92
# 3             Stay  The Kid LAROI  Hip-Hop          180          92
# 4          Peaches  Justin Bieber      R&B          237          73
#
#    Danceability  Energy  Tempo  Loudness  Acousticness  StreamsMillions
# 0          0.46    0.56    108     -10.7          0.10             2283
# 1          0.66    0.42    107      -9.9          0.52             2348
# 2          0.77    0.72    108      -8.0          0.24               76
# 3          0.66    0.56    107      -3.4          0.29              429
# 4          0.63    0.60    113      -4.7          0.62             2246

# %%
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]

# %%
X
# Out:
#                 Track            Artist        Genre  DurationSec  Popularity  \
# 0     Blinding Lights        The Weeknd          Pop          303          73
# 1          Levitating          Dua Lipa          Pop          162          88
# 2        Shape of You        Ed Sheeran          Pop          190          92
# 3                Stay     The Kid LAROI      Hip-Hop          180          92
# 4             Peaches     Justin Bieber          R&B          237          73
# 5             Bad Guy     Billie Eilish  Alternative          171          99
# 6           Sunflower       Post Malone      Hip-Hop          189          92
# 7              Closer  The Chainsmokers          EDM          165          82
# 8    Watermelon Sugar      Harry Styles          Pop          319          99
# 9           As It Was      Harry Styles          Pop          258          82
# 10           Senorita      Shawn Mendes    Latin Pop          198          96
# ...
